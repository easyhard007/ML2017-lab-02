# %%
from sklearn.externals.joblib import Memory
from sklearn.datasets import load_svmlight_file
import numpy as np
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import random
import math

eta = 0.001 # Learning Rate
iter = 1000 # Iteration times
accuracy = 0.001 # If loss<accuracy , then stop iteration
mini_batch_percent = 0.1

m_train = 32561 # Amount of training data
m_test = 16281 # Amount of testing data
features=123 # Fearures of dataset

#Initialize arrays
w= [0]*features #All zero initialization

#used to stastic and draw graph
iter_num = [0]*iter;
loss_train  = [0]*iter;
loss_test  = [0]*iter;
acc_train = [0]*iter;
acc_test = [0]*iter;

#Use to get dataset from file
def get_data():
    data_train = load_svmlight_file("dataset\\a9a",n_features=features)
    X_train = data_train[0].toarray()
    y_train = data_train[1]
    data_test = load_svmlight_file("dataset\\a9a.t",n_features=features)
    X_test = data_test[0].toarray()
    y_test = data_test[1]
    return X_train, y_train, X_test, y_test

#The linear model, hw(x) = g(w.T * x)
def hypothesis(x):
    global w
    z =   np.mat(x) * np.mat(w).T
    z = z[0,0]
    result = 1 / (1+(np.e**(-z)))
    return result


#Loss function 
def loss(m,X,y):
    global w
    result = 0.0
    w2 = np.mat(w)
    for i in range (0,m):
        x = np.mat(X[i])
        result += np.log(1+np.e**(-(X[i] * w2.T)[0,0]*y[i]))
    result = result /m 
    return result



#mini -batch loss function  
def SGD_loss(m,X,y):
    sum = 0.0
    sample_num =math.ceil( m * mini_batch_percent)
    target = np.random.permutation(m)[0:sample_num]
    
    X_new  = X[ target: ]
    y_new = y[target]
    
    return sum (np.log(1+np.e**(-y_new*(X_new * w.T)))) / m

def update(m,X,y):
    global w
    w = w - eta * grad2(m,X,y)

#Derivative the Loss function to get Gradient (G) of theta j
def grad2(m,X,y):
    result = np.zeros(features);
    for i in range (0,m):
        result +=  (hypothesis(X[i]) - y[i])*X[i]
    result = result / m
    return result

#Derivative the Loss function to get Gradient (G) of theta j
def grad(m,X,y):
    result = [0]*features
    for i in range (0,m):
        rate = hypothesis(X[i])  - y[i]
        for j in range (0,features):
            result[j] += rate * X[i][j]
    for j in range (0,features):
        result[j]  =  result[j] / m
    result = np.mat(result)
    return result

#Train and validate 
#def trainAndTest():
    
        
            
def information():
    print("Loss of train:", loss_train)
    print("Loss of valitation",loss_test)

    
#test

a=[1,2,3]
b=[1,1,2]
a = np.mat(a)
b = np.mat(b)
c=  a * b.T
print(c[0,0])


#Main 
X_train, y_train, X_test, y_test = get_data()
m_train = 100
X_train = X_train[0:100]
y_train = y_train[0:100]
print(hypothesis(X_train[0]))

for i in range(0,iter):
    print("loss:",loss(m_train,X_train,y_train))
    for i2 in range(0,10):
        update(m_train,X_train,y_train)


#Print the information and draw graphs
print("Features:",w)
fig, ax = plt.subplots()
ax.plot(iter_num, loss_train,color = 'm', label='loss of train')
ax.plot(iter_num, loss_test, color = 'c', label='loss of validation')
plt.legend(bbox_to_anchor=[1, 1])  
ax.set_xlabel('Iteration times')
ax.set_ylabel('Loss')
plt.show()  

fig2, ax2 = plt.subplots()
ax2.plot(iter_num, acc_train,color = 'm', label='Acc of train')
ax2.plot(iter_num, acc_test, color = 'c', label='Acc of validation')
plt.legend(bbox_to_anchor=[1, 1])  
ax2.set_xlabel('Iteration times')
ax2.set_ylabel('Accuracy Rate')
plt.show()
# Out:
# 9
# 0.5
# loss: 0.69314718056
# loss: 0.677149200018
# loss: 0.662337680016
# loss: 0.64866149318
# loss: 0.636069565825
# loss: 0.624511246512
# loss: 0.613936625885
# loss: 0.604296808524
# loss: 0.595544138724
# loss: 0.587632382964
# loss: 0.580516872455
# loss: 0.574154609532
# loss: 0.568504341835
# loss: 0.563526608232
# loss: 0.559183760367
# loss: 0.555439963483
# loss: 0.552261179936
# loss: 0.549615138511
# loss: 0.547471292342
# loss: 0.545800767904
# loss: 0.544576307247
# loss: 0.543772205339
# loss: 0.543364244106
# loss: 0.543329624505
# loss: 0.543646897747
# loss: 0.544295896576
# loss: 0.545257667331
# loss: 0.546514403388
# loss: 0.54804938041
# loss: 0.549846893757
# loss: 0.551892198299
# loss: 0.554171450786
# loss: 0.556671654895
# loss: 0.559380608983
# loss: 0.562286856573
# loss: 0.565379639527
# loss: 0.568648853873
# loss: 0.572085008194
# loss: 0.575679184508
# loss: 0.579423001535
# loss: 0.583308580241
# loss: 0.587328511561
# loss: 0.59147582618
# loss: 0.595743966269
# loss: 0.600126759062
# loss: 0.604618392166
# loss: 0.609213390499
# loss: 0.613906594767
# loss: 0.618693141362
# loss: 0.623568443612
# loss: 0.62852817428
# loss: 0.633568249235
# loss: 0.638684812216
# loss: 0.643874220621
# loss: 0.649133032242
# loss: 0.654457992884
# loss: 0.659846024817
# loss: 0.665294215992
# loss: 0.67079980997
# loss: 0.676360196525
# loss: 0.681972902861
# loss: 0.687635585406
# loss: 0.693346022148
# loss: 0.699102105466
# loss: 0.70490183543
# loss: 0.710743313532
# loss: 0.716624736821
# loss: 0.722544392417
# loss: 0.728500652366
# loss: 0.734491968831
# loss: 0.74051686958
# loss: 0.746573953762
# loss: 0.752661887939
# loss: 0.758779402372
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-0908f2d12a43> in <module>()
#     123     print("loss:",loss(m_train,X_train,y_train))
#     124     for i2 in range(0,10):
# --> 125         update(m_train,X_train,y_train)
#     126
#     127
#
# <ipython-input-18-0908f2d12a43> in update(m, X, y)
#      71 def update(m,X,y):
#      72     global w
# ---> 73     w = w - eta * grad2(m,X,y)
#      74
#      75 #Derivative the Loss function to get Gradient (G) of theta j
#
# <ipython-input-18-0908f2d12a43> in grad2(m, X, y)
#      77     result = np.zeros(features);
#      78     for i in range (0,m):
# ---> 79         result +=  (hypothesis(X[i]) - y[i])*X[i]
#      80     result = result / m
#      81     return result
#
# <ipython-input-18-0908f2d12a43> in hypothesis(x)
#      39 def hypothesis(x):
#      40     global w
# ---> 41     z =   np.mat(x) * np.mat(w).T
#      42     z = z[0,0]
#      43     result = 1 / (1+(np.e**(-z)))
#
# c:\program files\python\python36\lib\site-packages\numpy\matrixlib\defmatrix.py in __mul__(self, other)
#     307         if isinstance(other, (N.ndarray, list, tuple)) :
#     308             # This promotes 1-D vectors to row vectors
# --> 309             return N.dot(self, asmatrix(other))
#     310         if isscalar(other) or not hasattr(other, '__rmul__') :
#     311             return N.dot(self, other)
#
# KeyboardInterrupt:
